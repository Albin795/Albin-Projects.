# %%
import numpy as np
import pandas as pd


a=pd.read_csv('Kerala climate.csv')
b=pd.read_csv('Kerala_Soil.csv')
c=pd.read_csv('kerala_groundwater.csv')
d=pd.read_csv('Kerala_Fertilizers.csv')
e=pd.read_csv('Pesticides_Kerala.csv')
f=pd.read_csv('Kerala Crop data.csv')



climate=pd.DataFrame(a[' Air Pressure'])

Soil=pd.DataFrame(b['K(kg/ha)'])

Water=pd.DataFrame(c['EC(microsiemens/cm)'])

Fertilizer=pd.DataFrame(d['DAP(tonnes)'])

Pesticides=pd.DataFrame(e['CARBOSULPHAN(QTY)(kg)'])

Crop1=pd.DataFrame(f['Rice(kg/hectare)'])
Crop2=pd.DataFrame(f['Jowar'])
Crop3=pd.DataFrame(f['Ragi'])
Crop4=pd.DataFrame(f['Small Millets'])
Crop5=pd.DataFrame(f['Tur '])
Crop6=pd.DataFrame(f['Other Pulses'])
Crop7=pd.DataFrame(f['Groundnuts'])
Crop8=pd.DataFrame(f['Sessasum'])
Crop9=pd.DataFrame(f['Tea'])
Crop10=pd.DataFrame(f['Banana'])
Crop11=pd.DataFrame(f['Sugarcane'])
Crop12=pd.DataFrame(f['Tobacco'])
Crop13=pd.DataFrame(f['Pepper'])
Crop14=pd.DataFrame(f['Chillies'])
Crop15=pd.DataFrame(f['Ginger'])
Crop16=pd.DataFrame(f['Coconut'])
Crop17=pd.DataFrame(f['Tumeric'])
Crop18=pd.DataFrame(f['Coffee'])
Crop19=pd.DataFrame(f['Rubber'])

Parameteronea=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop1],axis=1)
Parameteroneb=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop2],axis=1)
Parameteronec=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop3],axis=1)
Parameteroned=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop4],axis=1)
Parameteronee=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop5],axis=1)
Parameteronef=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop6],axis=1)
Parameteroneg=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop7],axis=1)
Parameteroneh=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop8],axis=1)
Parameteronei=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop9],axis=1)
Parameteronej=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop10],axis=1)
Parameteronek=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop11],axis=1)
Parameteronel=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop12],axis=1)
Parameteronem=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop13],axis=1)
Parameteronen=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop14],axis=1)
Parameteroneo=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop15],axis=1)
Parameteronep=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop16],axis=1)
Parameteroneq=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop17],axis=1)
Parameteroner=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop18],axis=1)
Parameterones=pd.concat([climate,Soil,Water,Fertilizer,Pesticides,Crop19],axis=1)

X0=Parameteronea.drop('Rice(kg/hectare)',axis=1)
y0=Parameteronea['Rice(kg/hectare)']

X1=Parameteroneb.drop('Jowar',axis=1)
y1=Parameteroneb['Jowar']

X2=Parameteronec.drop('Ragi',axis=1)
y2=Parameteronec['Ragi']

X3=Parameteroned.drop('Small Millets',axis=1)
y3=Parameteroned['Small Millets']

X4=Parameteronee.drop('Tur ',axis=1)
y4=Parameteronee['Tur ']

X5=Parameteronef.drop('Other Pulses',axis=1)
y5=Parameteronef['Other Pulses']

X6=Parameteroneg.drop('Groundnuts',axis=1)
y6=Parameteroneg['Groundnuts']

X7=Parameteroneh.drop('Sessasum',axis=1)
y7=Parameteroneh['Sessasum']

X8=Parameteronei.drop('Tea',axis=1)
y8=Parameteronei['Tea']

X9=Parameteronej.drop('Banana',axis=1)
y9=Parameteronej['Banana']

X10=Parameteronek.drop('Sugarcane',axis=1)
y10=Parameteronek['Sugarcane']

X11=Parameteronel.drop('Tobacco',axis=1)
y11=Parameteronel['Tobacco']

X12=Parameteronem.drop('Pepper',axis=1)
y12=Parameteronem['Pepper']

X13=Parameteronen.drop('Chillies',axis=1)
y13=Parameteronen['Chillies']

X14=Parameteroneo.drop('Ginger',axis=1)
y14=Parameteroneo['Ginger']

X15=Parameteronep.drop('Coconut',axis=1)
y15=Parameteronep['Coconut']

X16=Parameteroneq.drop('Tumeric',axis=1)
y16=Parameteroneq['Tumeric']

X17=Parameteroner.drop('Coffee',axis=1)
y17=Parameteroner['Coffee']

X18=Parameterones.drop('Rubber',axis=1)
y18=Parameterones['Rubber']

from sklearn.model_selection import train_test_split

X_train0, X_test0, y_train0, y_test0 = train_test_split(X0, y0, test_size=0.70,random_state=70)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.70,random_state=70)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.70,random_state=70)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.70,random_state=70)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4, y4, test_size=0.70,random_state=70)
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5, y5, test_size=0.70,random_state=70)
X_train6, X_test6, y_train6, y_test6 = train_test_split(X6, y6, test_size=0.70,random_state=70)
X_train7, X_test7, y_train7, y_test7 = train_test_split(X7, y7, test_size=0.70,random_state=70)
X_train8, X_test8, y_train8, y_test8 = train_test_split(X8, y8, test_size=0.70,random_state=70)
X_train9, X_test9, y_train9, y_test9 = train_test_split(X9, y9, test_size=0.70,random_state=70)
X_train10, X_test10, y_train10, y_test10 = train_test_split(X10, y10, test_size=0.70,random_state=70)
X_train11, X_test11, y_train11, y_test11 = train_test_split(X11, y11, test_size=0.70,random_state=70)
X_train12, X_test12, y_train12, y_test12 = train_test_split(X12, y12, test_size=0.70,random_state=70)
X_train13, X_test13, y_train13, y_test13 = train_test_split(X13, y13, test_size=0.70,random_state=70)
X_train14, X_test14, y_train14, y_test14 = train_test_split(X14, y14, test_size=0.70,random_state=70)
X_train15, X_test15, y_train15, y_test15 = train_test_split(X15, y15, test_size=0.70,random_state=70)
X_train16, X_test16, y_train16, y_test16 = train_test_split(X16, y16, test_size=0.70,random_state=70)
X_train17, X_test17, y_train17, y_test17 = train_test_split(X17, y17, test_size=0.70,random_state=70)
X_train18, X_test18, y_train18, y_test18 = train_test_split(X18, y18, test_size=0.70,random_state=70)


from sklearn.ensemble import RandomForestClassifier

a=RandomForestClassifier()
b=RandomForestClassifier()
c=RandomForestClassifier()
d=RandomForestClassifier()
e=RandomForestClassifier()
f=RandomForestClassifier()
g=RandomForestClassifier()
h=RandomForestClassifier()
i=RandomForestClassifier()
j=RandomForestClassifier()
k=RandomForestClassifier()
l=RandomForestClassifier()
m=RandomForestClassifier()
n=RandomForestClassifier()
o=RandomForestClassifier()
p=RandomForestClassifier()
q=RandomForestClassifier()
r=RandomForestClassifier()
s=RandomForestClassifier()

a.fit(X_train0,y_train0)
b.fit(X_train1,y_train1)
c.fit(X_train2,y_train2)
d.fit(X_train3,y_train3)
e.fit(X_train4,y_train4)
f.fit(X_train5,y_train5)
g.fit(X_train6,y_train6)
h.fit(X_train7,y_train7)
i.fit(X_train8,y_train8)
j.fit(X_train9,y_train9)
k.fit(X_train10,y_train10)
l.fit(X_train11,y_train11)
m.fit(X_train12,y_train12)
n.fit(X_train13,y_train13)
o.fit(X_train14,y_train14)
p.fit(X_train15,y_train15)
q.fit(X_train16,y_train16)
r.fit(X_train17,y_train17)
s.fit(X_train18,y_train18)

print(a.score(X_test0,y_test0)*10)
print(b.score(X_test1,y_test1)*10)
print(c.score(X_test2,y_test2)*10)
print(d.score(X_test3,y_test3)*10)
print(e.score(X_test4,y_test4)*10)
print(f.score(X_test5,y_test5)*10)
print(g.score(X_test6,y_test6))
print(h.score(X_test7,y_test7)*10)
print(i.score(X_test8,y_test8))
print(j.score(X_test9,y_test9)*10)
print(k.score(X_test10,y_test10)*10)
print(l.score(X_test11,y_test11))
print(m.score(X_test12,y_test12))
print(n.score(X_test13,y_test13))
print(o.score(X_test14,y_test14)*10)
print(p.score(X_test15,y_test15)*10)
print(q.score(X_test16,y_test16))
print(r.score(X_test17,y_test17)*10)
print(s.score(X_test18,y_test18)*10)
# Out:
# 0.4225352112676056
# 0.5633802816901409
# 0.14084507042253522
# 0.14084507042253522
# 0.0
# 0.28169014084507044
# 0.04225352112676056
# 0.0
# 0.19718309859154928
# 0.5633802816901409
# 0.28169014084507044
# 0.056338028169014086
# 0.09859154929577464
# 0.1267605633802817
# 0.14084507042253522
# 0.8450704225352113
# 0.09859154929577464
# 0.0
# 0.14084507042253522
